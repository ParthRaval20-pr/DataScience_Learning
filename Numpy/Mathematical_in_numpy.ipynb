# %%
import numpy as np

# %%
arr = np.array([10,54,60,95,22])

# %%
np.mean(arr)
# Out:
# np.float64(48.2)

# %%
np.std(arr)
# Out:
# np.float64(30.029319006597536)

# %%
np.var(arr)
# Out:
# np.float64(901.76)

# %%
np.min(arr)
# Out:
# np.int64(10)

# %%
np.max(arr)
# Out:
# np.int64(95)

# %%
np.sum(arr)
# Out:
# np.int64(241)

# %%
np.prod(arr)
# Out:
# np.int64(67716000)

# %%
np.median(arr)
# Out:
# np.float64(54.0)

# %%
np.percentile(arr, 50)  # For the 50th percentile (median)
# Out:
# np.float64(54.0)

# %%
np.argmin(arr)
# Out:
# np.int64(0)

# %%
np.argmax(arr)
# Out:
# np.int64(3)

# %%
arr1 = np.array([50,30,25,65])
arr2 = np.array([55,35,30,70])
np.corrcoef(arr1, arr2)
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
np.unique(arr)
# Out:
# array([10, 22, 54, 60, 95])

# %%
np.diff(arr)
# Out:
# array([ 44,   6,  35, -73])

# %%
np.cumsum(arr)
# Out:
# array([ 10,  64, 124, 219, 241])

# %%
np.linspace(0, 10, 5)  # 5 numbers from 0 to 10
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
np.log(arr)
# Out:
# array([2.30258509, 3.98898405, 4.09434456, 4.55387689, 3.09104245])

# %%
np.exp(arr)
# Out:
# array([2.20264658e+04, 2.83075330e+23, 1.14200739e+26, 1.81123908e+41,
#        3.58491285e+09])
